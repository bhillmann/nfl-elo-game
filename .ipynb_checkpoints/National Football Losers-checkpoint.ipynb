# %%
import pandas as pd
from util import *
from forecast import *
import matplotlib.pyplot as plt
from hungarian import *

# %%
# %matplotlib inline

# %%
#Load up the elo dataframe
games = Util.read_games("data/nfl_games.csv")
forecasts = Forecast.forecast(games)
elos = pd.DataFrame(games)

# %%
elos.tail()
# Out:
#             date elo1 elo2    elo_diff  elo_prob1  my_prob1  neutral  playoff  \
# 15982 2017-12-31            215.650300        NaN       NaN        0        0
# 15981 2017-12-31            125.685010        NaN       NaN        0        0
# 15980 2017-12-31            113.361158        NaN       NaN        0        0
# 15986 2017-12-31            372.577130        NaN       NaN        0        0
# 15995 2017-12-31            146.116797        NaN       NaN        0        0
#
#        result1  score1  score2  season team1 team2  week_in_season
# 15982      NaN     NaN     NaN    2017   MIN   CHI              17
# 15981      NaN     NaN     NaN    2017   MIA   BUF              17
# 15980      NaN     NaN     NaN    2017   IND   HOU              17
# 15986      NaN     NaN     NaN    2017   PIT   CLE              17
# 15995      NaN     NaN     NaN    2017   LAR    SF              17

# %%
elos.dtypes
# Out:
# date          object
# elo1          object
# elo2          object
# elo_diff     float64
# elo_prob1    float64
# my_prob1     float64
# neutral        int64
# playoff        int64
# result1      float64
# score1       float64
# score2       float64
# season         int64
# team1         object
# team2         object
# dtype: object

# %%
# Convert to datetime objects
#elos['season'] = pd.to_datetime(elos['season'], errors='coerce')
elos['date'] = pd.to_datetime(elos['date'], errors='coerce')

# %%
elos.dtypes
# Out:
# date         datetime64[ns]
# elo1                 object
# elo2                 object
# elo_diff            float64
# elo_prob1           float64
# my_prob1            float64
# neutral               int64
# playoff               int64
# result1             float64
# score1              float64
# score2              float64
# season                int64
# team1                object
# team2                object
# dtype: object

# %%
elos = elos.sort_values('date', ascending=True)

# %%
week_in_season = []
# Get week in season for forecasting
for group, df in elos.groupby('season'):
    df = df.sort_values('date', ascending=True)
    teams_played = set()
    week = 1
    for team1, team2 in zip(df['team1'], df['team2']):
        if team1 in teams_played or team2 in teams_played:
            week += 1
            teams_played = set()
        teams_played.add(team1)
        teams_played.add(team2)
        week_in_season.append(week)
elos['week_in_season'] = week_in_season

# %%
elos[elos['season'].isin([2016])]
# Out:
#             date              elo1              elo2    elo_diff  elo_prob1  \
# 15473 2016-09-08   1637.1131581531  1633.57926535012  102.703824   0.597369
# 15481 2016-09-11  1505.68227372661  1444.02306103417  160.998832   0.674610
# 15486 2016-09-11  1612.61322429379   1605.4217557152  106.942242   0.602422
# 15485 2016-09-11  1445.98789369703  1468.87798186004   74.634753   0.560306
# 15484 2016-09-11  1484.30206131341  1502.85315875748   86.216001   0.566450
# 15483 2016-09-11  1634.55869815528  1438.73814816582  305.053106   0.817784
# 15482 2016-09-11  1475.49833239743  1518.80808993309   60.909969   0.531174
# 15479 2016-09-11  1485.83297419564  1412.23649632018  174.789349   0.689509
# 15478 2016-09-11  1522.16390912172  1578.45811806017   40.861462   0.512526
# 15477 2016-09-11  1388.72405911239  1582.43588564451 -103.682375   0.322802
# 15731   MIA              18
# 15732   NYG              18
# 15734   HOU              19
# 15733   SEA              19
# 15735    GB              19
# 15736   PIT              19
# 15737    GB              20
# 15738   PIT              20
# 15739    NE              21
#
# [267 rows x 15 columns]

# %%
plt.hist(elos.groupby(['season', 'week_in_season']).sum()['elo_diff'])
plt.show()

# %%
elos_visitor = elos.copy()
elos_visitor['elo_prob1'] = 1 - elos['elo_prob1']
elos_visitor['team1'] = elos['team2']
elos_visitor['team2'] = elos['team1']
elos_visitor['result1'] = 1 - elos['result1']


elos_both = elos.append(elos_visitor)

for year, group in elos_both[elos_both['season'] > 2000].groupby('season'):
    if year == 2017:
        break
    teams = dict(zip(set(group['team1']), range(len(set(group['team1'])))))
    data = np.ones((len(teams), len(teams)))
    data = data*1000
    for _, row in group[group['week_in_season'] <= 15].iterrows():
        data[teams[row['team1']], row['week_in_season']-1] = row['elo_prob1']
    hungarian = Hungarian(data)
    hungarian.calculate()
    number_to_team = dict(zip(teams.values(), teams.keys()))
    print(hungarian.get_total_potential())
    for _team, _week in hungarian.get_results():
        if _week < 17:
            temp = group[group['team1'] == number_to_team[_team]]
            temp = temp[temp['week_in_season'] == _week + 1]['result1']
            print(temp)
            print("%d,%s,%d,%d" % (_week+1, number_to_team[_team], year, temp))
# Out:
# 16002.8433625
# 11591    0.0
# Name: result1, dtype: float64
# 9,CAR,2001,0
# 11550    1.0
# Name: result1, dtype: float64
# 6,ATL,2001,1
# 11669    0.0
# Name: result1, dtype: float64
# 14,CIN,2001,0
# 11588    0.0
# Name: result1, dtype: float64
# 8,DEN,2001,0
# 11686    0.0
# Name: result1, dtype: float64
# 15,DET,2001,0
# 11564    1.0
# Name: result1, dtype: float64
# 7,NO,2001,1
# 11486    0.0
# Name: result1, dtype: float64
# 1,CHI,2001,0
# 11633    1.0
# Name: result1, dtype: float64
# 11,TB,2001,1
# 11652    0.0
# Name: result1, dtype: float64
# 13,KC,2001,0
# 11534    0.0
# Name: result1, dtype: float64
# 5,ARI,2001,0
# 11523    0.0
# Name: result1, dtype: float64
# 4,DAL,2001,0
# 11617    0.0
# Name: result1, dtype: float64
# 10,LAC,2001,0
# 11504    0.0
# Name: result1, dtype: float64
# 2,WSH,2001,0
# 11512    1.0
# Name: result1, dtype: float64
# 3,CLE,2001,1
# 11645    0.0
# Name: result1, dtype: float64
# 12,BUF,2001,0
# 11695    0.0
# Name: result1, dtype: float64
# 16,MIN,2001,0
# 11722    1.0
# Name: result1, dtype: float64
# 17,MIA,2001,1
# 17002.839355
# 11944    0.0
# Name: result1, dtype: float64
# 15,WSH,2002,0
# 11901    0.0
# Name: result1, dtype: float64
# 12,CIN,2002,0
# 11891    0.0
# Name: result1, dtype: float64
# 11,CAR,2002,0
# 11915    0.0
# Name: result1, dtype: float64
# 13,CHI,2002,0
# 11813    0.0
# Name: result1, dtype: float64
# 6,CLE,2002,0
# 11930    1.0
# Name: result1, dtype: float64
# 14,HOU,2002,1
# 11772    0.0
# Name: result1, dtype: float64
# 3,KC,2002,0
# 11853    0.0
# Name: result1, dtype: float64
# 9,MIN,2002,0
# 11749    0.0
# Name: result1, dtype: float64
# 1,ATL,2002,0
# 11874    0.0
# Name: result1, dtype: float64
# 10,DET,2002,0
# 11793    1.0
# Name: result1, dtype: float64
# 4,DAL,2002,1
# 11824    0.0
# Name: result1, dtype: float64
# 7,SEA,2002,0
# 11840    0.0
# Name: result1, dtype: float64
# 8,ARI,2002,0
# 11765    1.0
# Name: result1, dtype: float64
# 2,NYG,2002,1
# 11805    0.0
# Name: result1, dtype: float64
# 5,BUF,2002,0
# 11959    0.0
# Name: result1, dtype: float64
# 16,MIA,2002,0
# 11976    1.0
# Name: result1, dtype: float64
# 17,OAK,2002,1
# 17003.0730839
# 12032    1.0
# Name: result1, dtype: float64
# 2,CAR,2003,1
# 12064    0.0
# Name: result1, dtype: float64
# 5,CIN,2003,0
# 12169    0.0
# Name: result1, dtype: float64
# 12,OAK,2003,0
# 12130    1.0
# Name: result1, dtype: float64
# 9,NO,2003,1
# 12146    0.0
# Name: result1, dtype: float64
# 11,JAX,2003,0
# 12142    0.0
# Name: result1, dtype: float64
# 10,CLE,2003,0
# 12092    0.0
# Name: result1, dtype: float64
# 7,CHI,2003,0
# 12211    0.0
# Name: result1, dtype: float64
# 15,ATL,2003,0
# 12198    0.0
# Name: result1, dtype: float64
# 14,DAL,2003,0
# 12087    0.0
# Name: result1, dtype: float64
# 6,PIT,2003,0
# 12058    0.0
# Name: result1, dtype: float64
# 4,DET,2003,0
# 12044    1.0
# Name: result1, dtype: float64
# 3,ARI,2003,1
# 12188    0.0
# Name: result1, dtype: float64
# 13,LAC,2003,0
# 12010    1.0
# Name: result1, dtype: float64
# 1,MIN,2003,1
# 12108    0.0
# Name: result1, dtype: float64
# 8,HOU,2003,0
# 12230    1.0
# Name: result1, dtype: float64
# 16,MIA,2003,1
# 12251    0.0
# Name: result1, dtype: float64
# 17,NYJ,2003,0
# 17002.8352935
# 12415    0.0
# Name: result1, dtype: float64
# 11,WSH,2004,0
# 12471    0.0
# Name: result1, dtype: float64
# 14,CIN,2004,0
# 12382    0.0
# Name: result1, dtype: float64
# 8,BAL,2004,0
# 12450    0.0
# Name: result1, dtype: float64
# 13,TEN,2004,0
# 12483    0.0
# Name: result1, dtype: float64
# 15,DAL,2004,0
# 12407    0.0
# Name: result1, dtype: float64
# 10,BUF,2004,0
# 12367    1.0
# Name: result1, dtype: float64
# 7,JAX,2004,1
# 12293    1.0
# Name: result1, dtype: float64
# 2,CHI,2004,1
# 12302    0.0
# Name: result1, dtype: float64
# 3,LAC,2004,0
# 12334    0.0
# Name: result1, dtype: float64
# 5,MIA,2004,0
# 12347    1.0
# Name: result1, dtype: float64
# 6,HOU,2004,1
# 12390    0.0
# Name: result1, dtype: float64
# 9,CLE,2004,0
# 12272    0.0
# Name: result1, dtype: float64
# 1,ARI,2004,0
# 12323    1.0
# Name: result1, dtype: float64
# 4,NYG,2004,1
# 12441    1.0
# Name: result1, dtype: float64
# 12,OAK,2004,1
# 12493    0.0
# Name: result1, dtype: float64
# 16,MIN,2004,0
# 12509    0.0
# Name: result1, dtype: float64
# 17,ATL,2004,0
# 17002.8312361
# 12742    1.0
# Name: result1, dtype: float64
# 14,MIA,2005,1
# 12602    0.0
# Name: result1, dtype: float64
# 5,WSH,2005,0
# 12536    0.0
# Name: result1, dtype: float64
# 1,OAK,2005,0
# 12693    0.0
# Name: result1, dtype: float64
# 11,NO,2005,0
# 12674    0.0
# Name: result1, dtype: float64
# 10,HOU,2005,0
# 12658    0.0
# Name: result1, dtype: float64
# 9,GB,2005,0
# 12715    0.0
# Name: result1, dtype: float64
# 13,TEN,2005,0
# 12711    0.0
# Name: result1, dtype: float64
# 12,PIT,2005,0
# 12586    1.0
# Name: result1, dtype: float64
# 4,LAC,2005,1
# 12623    0.0
# Name: result1, dtype: float64
# 6,LAR,2005,0
# 12637    0.0
# Name: result1, dtype: float64
# 7,NYJ,2005,0
# 12651    0.0
# Name: result1, dtype: float64
# 8,BAL,2005,0
# 12562    0.0
# Name: result1, dtype: float64
# 2,JAX,2005,0
# 12570    0.0
# Name: result1, dtype: float64
# 3,CLE,2005,0
# 12756    0.0
# Name: result1, dtype: float64
# 15,SF,2005,0
# 12773    0.0
# Name: result1, dtype: float64
# 16,MIN,2005,0
# 12787    0.0
# Name: result1, dtype: float64
# 17,ATL,2005,0
# 17002.52432
# 12954    0.0
# Name: result1, dtype: float64
# 11,ATL,2006,0
# 12878    0.0
# Name: result1, dtype: float64
# 6,OAK,2006,0
# 12844    0.0
# Name: result1, dtype: float64
# 3,NYG,2006,0
# 12874    0.0
# Name: result1, dtype: float64
# 5,TEN,2006,0
# 12893    0.0
# Name: result1, dtype: float64
# 7,WSH,2006,0
# 13018    0.0
# Name: result1, dtype: float64
# 15,TB,2006,0
# 12992    0.0
# Name: result1, dtype: float64
# 13,DET,2006,0
# 12833    0.0
# Name: result1, dtype: float64
# 2,HOU,2006,0
# 12974    0.0
# Name: result1, dtype: float64
# 12,PHI,2006,0
# 12928    0.0
# Name: result1, dtype: float64
# 9,CLE,2006,0
# 12915    0.0
# Name: result1, dtype: float64
# 8,SF,2006,0
# 12803    0.0
# Name: result1, dtype: float64
# 1,MIA,2006,0
# 12852    0.0
# Name: result1, dtype: float64
# 4,ARI,2006,0
# 13010    0.0
# Name: result1, dtype: float64
# 14,LAR,2006,0
# 12941    0.0
# Name: result1, dtype: float64
# 10,BUF,2006,0
# 13027    0.0
# Name: result1, dtype: float64
# 16,MIN,2006,0
# 13047    1.0
# Name: result1, dtype: float64
# 17,CAR,2006,1
# 17002.5792715
# 13198    1.0
# Name: result1, dtype: float64
# 9,MIN,2007,1
# 13168    0.0
# Name: result1, dtype: float64
# 7,MIA,2007,0
# 13087    0.0
# Name: result1, dtype: float64
# 2,OAK,2007,0
# 13289    0.0
# Name: result1, dtype: float64
# 15,NYJ,2007,0
# 13121    0.0
# Name: result1, dtype: float64
# 4,DEN,2007,0
# 13261    0.0
# Name: result1, dtype: float64
# 13,BAL,2007,0
# 13070    0.0
# Name: result1, dtype: float64
# 1,NO,2007,0
# 13139    0.0
# Name: result1, dtype: float64
# 5,CLE,2007,0
# 13173    0.0
# Name: result1, dtype: float64
# 8,WSH,2007,0
# 13225    0.0
# Name: result1, dtype: float64
# 11,KC,2007,0
# 13240    0.0
# Name: result1, dtype: float64
# 12,PHI,2007,0
# 13112    0.0
# Name: result1, dtype: float64
# 3,BUF,2007,0
# 13272    0.0
# Name: result1, dtype: float64
# 14,CAR,2007,0
# 13213    0.0
# Name: result1, dtype: float64
# 10,SF,2007,0
# 13157    0.0
# Name: result1, dtype: float64
# 6,LAR,2007,0
# 13305    0.0
# Name: result1, dtype: float64
# 16,ATL,2007,0
# 13318    1.0
# Name: result1, dtype: float64
# 17,CIN,2007,1
# 17002.7965612
# 13376    1.0
# Name: result1, dtype: float64
# 3,MIA,2008,1
# 13404    1.0
# Name: result1, dtype: float64
# 5,ATL,2008,1
# 13534    0.0
# Name: result1, dtype: float64
# 14,CIN,2008,0
# 13357    0.0
# Name: result1, dtype: float64
# 2,NYJ,2008,0
# 13415    0.0
# Name: result1, dtype: float64
# 6,BAL,2008,0
# 13454    0.0
# Name: result1, dtype: float64
# 9,DET,2008,0
# 13392    1.0
# Name: result1, dtype: float64
# 4,WSH,2008,1
# 13474    0.0
# Name: result1, dtype: float64
# 10,BUF,2008,0
# 13487    0.0
# Name: result1, dtype: float64
# 11,HOU,2008,0
# 13343    0.0
# Name: result1, dtype: float64
# 1,KC,2008,0
# 13560    0.0
# Name: result1, dtype: float64
# 15,CLE,2008,0
# 13445    0.0
# Name: result1, dtype: float64
# 8,LAR,2008,0
# 13503    1.0
# Name: result1, dtype: float64
# 12,OAK,2008,1
# 13429    0.0
# Name: result1, dtype: float64
# 7,SF,2008,0
# 13526    1.0
# Name: result1, dtype: float64
# 13,DEN,2008,1
# 13564    0.0
# Name: result1, dtype: float64
# 16,MIN,2008,0
# 13578    1.0
# Name: result1, dtype: float64
# 17,CAR,2008,1
# 17002.5331815
# 13740    0.0
# Name: result1, dtype: float64
# 10,DET,2009,0
# 13802    0.0
# Name: result1, dtype: float64
# 14,DEN,2009,0
# 13662    0.0
# Name: result1, dtype: float64
# 4,SEA,2009,0
# 13776    0.0
# Name: result1, dtype: float64
# 12,CHI,2009,0
# 13648    0.0
# Name: result1, dtype: float64
# 3,KC,2009,0
# 13718    0.0
# Name: result1, dtype: float64
# 8,SF,2009,0
# 13759    0.0
# Name: result1, dtype: float64
# 11,WSH,2009,0
# 13725    0.0
# Name: result1, dtype: float64
# 9,CAR,2009,0
# 13681    0.0
# Name: result1, dtype: float64
# 6,CLE,2009,0
# 13695    0.0
# Name: result1, dtype: float64
# 7,LAR,2009,0
# 13618    0.0
# Name: result1, dtype: float64
# 1,BUF,2009,0
# 13673    0.0
# Name: result1, dtype: float64
# 5,TB,2009,0
# 13629    1.0
# Name: result1, dtype: float64
# 2,HOU,2009,1
# 13792    1.0
# Name: result1, dtype: float64
# 13,OAK,2009,1
# 13812    0.0
# Name: result1, dtype: float64
# 15,JAX,2009,0
# 13843    0.0
# Name: result1, dtype: float64
# 16,MIN,2009,0
# 13853    0.0
# Name: result1, dtype: float64
# 17,MIA,2009,0
# 17003.072422
# 13882    0.0
# Name: result1, dtype: float64
# 1,OAK,2010,0
# 14032    0.0
# Name: result1, dtype: float64
# 12,CIN,2010,0
# 13911    0.0
# Name: result1, dtype: float64
# 3,DET,2010,0
# 14006    1.0
# Name: result1, dtype: float64
# 10,DAL,2010,1
# 13995    0.0
# Name: result1, dtype: float64
# 9,TB,2010,0
# 13894    0.0
# Name: result1, dtype: float64
# 2,JAX,2010,0
# 13961    0.0
# Name: result1, dtype: float64
# 7,BUF,2010,0
# 14052    0.0
# Name: result1, dtype: float64
# 13,SF,2010,0
# 14065    0.0
# Name: result1, dtype: float64
# 14,LAR,2010,0
# 13957    0.0
# Name: result1, dtype: float64
# 6,CLE,2010,0
# 13922    1.0
# Name: result1, dtype: float64
# 4,WSH,2010,1
# 13934    0.0
# Name: result1, dtype: float64
# 5,KC,2010,0
# 14090    0.0
# Name: result1, dtype: float64
# 15,DEN,2010,0
# 14024    0.0
# Name: result1, dtype: float64
# 11,SEA,2010,0
# 13987    0.0
# Name: result1, dtype: float64
# 8,HOU,2010,0
# 14110    1.0
# Name: result1, dtype: float64
# 16,MIN,2010,1
# 14121    0.0
# Name: result1, dtype: float64
# 17,MIA,2010,0
# 17002.5639939
# 14283    0.0
# Name: result1, dtype: float64
# 10,MIN,2011,0
# 14207    0.0
# Name: result1, dtype: float64
# 5,NYJ,2011,0
# 14191    0.0
# Name: result1, dtype: float64
# 4,DEN,2011,0
# 14360    1.0
# Name: result1, dtype: float64
# 15,CAR,2011,1
# 14138    0.0
# Name: result1, dtype: float64
# 1,NO,2011,0
# 14305    0.0
# Name: result1, dtype: float64
# 12,BUF,2011,0
# 14286    0.0
# Name: result1, dtype: float64
# 11,TB,2011,0
# 14240    1.0
# Name: result1, dtype: float64
# 7,JAX,2011,1
# 14319    0.0
# Name: result1, dtype: float64
# 13,IND,2011,0
# 14251    0.0
# Name: result1, dtype: float64
# 8,ARI,2011,0
# 14341    0.0
# Name: result1, dtype: float64
# 14,OAK,2011,0
# 14167    0.0
# Name: result1, dtype: float64
# 2,SEA,2011,0
# 14170    0.0
# Name: result1, dtype: float64
# 3,KC,2011,0
# 14218    0.0
# Name: result1, dtype: float64
# 6,LAR,2011,0
# 14262    0.0
# Name: result1, dtype: float64
# 9,CLE,2011,0
# 14373    0.0
# Name: result1, dtype: float64
# 16,MIA,2011,0
# 14378    0.0
# Name: result1, dtype: float64
# 17,WSH,2011,0
# 17002.6887897
# 14589    0.0
# Name: result1, dtype: float64
# 13,MIN,2012,0
# 14505    0.0
# Name: result1, dtype: float64
# 7,NYJ,2012,0
# 14479    0.0
# Name: result1, dtype: float64
# 5,DEN,2012,0
# 14545    0.0
# Name: result1, dtype: float64
# 10,BUF,2012,0
# 14563    0.0
# Name: result1, dtype: float64
# 11,JAX,2012,0
# 14573    0.0
# Name: result1, dtype: float64
# 12,KC,2012,0
# 14619    0.0
# Name: result1, dtype: float64
# 15,IND,2012,0
# 14610    0.0
# Name: result1, dtype: float64
# 14,MIA,2012,0
# 14493    0.0
# Name: result1, dtype: float64
# 6,OAK,2012,0
# 14412    1.0
# Name: result1, dtype: float64
# 1,WSH,2012,1
# 14453    0.0
# Name: result1, dtype: float64
# 4,CLE,2012,0
# 14518    0.0
# Name: result1, dtype: float64
# 8,CAR,2012,0
# 14530    0.0
# Name: result1, dtype: float64
# 9,DAL,2012,0
# 14424    1.0
# Name: result1, dtype: float64
# 2,ARI,2012,1
# 14448    0.0
# Name: result1, dtype: float64
# 3,LAR,2012,0
# 14629    1.0
# Name: result1, dtype: float64
# 16,ATL,2012,1
# 14654    0.0
# Name: result1, dtype: float64
# 17,DET,2012,0
# 17002.7877403
# 14832    0.0
# Name: result1, dtype: float64
# 11,MIN,2013,0
# 14787    0.0
# Name: result1, dtype: float64
# 8,WSH,2013,0
# 14834    0.0
# Name: result1, dtype: float64
# 12,ATL,2013,0
# 14719    0.0
# Name: result1, dtype: float64
# 3,OAK,2013,0
# 14747    0.0
# Name: result1, dtype: float64
# 5,DET,2013,0
# 14729    0.0
# Name: result1, dtype: float64
# 4,PHI,2013,0
# 14867    0.0
# Name: result1, dtype: float64
# 14,TEN,2013,0
# 14880    1.0
# Name: result1, dtype: float64
# 15,LAC,2013,1
# 14817    1.0
# Name: result1, dtype: float64
# 10,LAR,2013,1
# 14688    0.0
# Name: result1, dtype: float64
# 2,NYJ,2013,0
# 14750    0.0
# Name: result1, dtype: float64
# 6,JAX,2013,0
# 14858    0.0
# Name: result1, dtype: float64
# 13,HOU,2013,0
# 14796    0.0
# Name: result1, dtype: float64
# 9,TB,2013,0
# 14770    0.0
# Name: result1, dtype: float64
# 7,CLE,2013,0
# 14676    0.0
# Name: result1, dtype: float64
# 1,BUF,2013,0
# 14897    0.0
# Name: result1, dtype: float64
# 16,MIA,2013,0
# 14917    1.0
# Name: result1, dtype: float64
# 17,CIN,2013,1
# 17002.8215257
# 15161    0.0
# Name: result1, dtype: float64
# 15,MIA,2014,0
# 15088    0.0
# Name: result1, dtype: float64
# 11,OAK,2014,0
# 15084    0.0
# Name: result1, dtype: float64
# 10,NYG,2014,0
# 15027    1.0
# Name: result1, dtype: float64
# 6,DAL,2014,1
# 14996    0.0
# Name: result1, dtype: float64
# 4,JAX,2014,0
# 15047    0.0
# Name: result1, dtype: float64
# 8,CHI,2014,0
# 15011    0.0
# Name: result1, dtype: float64
# 5,HOU,2014,0
# 14939    0.0
# Name: result1, dtype: float64
# 1,GB,2014,0
# 14961    0.0
# Name: result1, dtype: float64
# 2,KC,2014,0
# 15071    1.0
# Name: result1, dtype: float64
# 9,LAR,2014,1
# 15127    0.0
# Name: result1, dtype: float64
# 13,WSH,2014,0
# 15030    0.0
# Name: result1, dtype: float64
# 7,NYJ,2014,0
# 15111    0.0
# Name: result1, dtype: float64
# 12,DET,2014,0
# 15145    0.0
# Name: result1, dtype: float64
# 14,TB,2014,0
# 14974    0.0
# Name: result1, dtype: float64
# 3,TEN,2014,0
# 15174    0.0
# Name: result1, dtype: float64
# 16,MIN,2014,0
# 15194    0.0
# Name: result1, dtype: float64
# 17,ATL,2014,0
# 17002.3344754
# 15311    0.0
# Name: result1, dtype: float64
# 8,MIA,2015,0
# 15410    1.0
# Name: result1, dtype: float64
# 14,OAK,2015,1
# 15300    0.0
# Name: result1, dtype: float64
# 7,NYJ,2015,0
# 15219    0.0
# Name: result1, dtype: float64
# 1,NYG,2015,0
# 15268    0.0
# Name: result1, dtype: float64
# 4,DET,2015,0
# 15421    0.0
# Name: result1, dtype: float64
# 15,TEN,2015,0
# 15365    0.0
# Name: result1, dtype: float64
# 11,BUF,2015,0
# 15242    0.0
# Name: result1, dtype: float64
# 3,JAX,2015,0
# 15395    1.0
# Name: result1, dtype: float64
# 13,PHI,2015,1
# 15229    1.0
# Name: result1, dtype: float64
# 2,TB,2015,1
# 15293    0.0
# Name: result1, dtype: float64
# 6,LAC,2015,0
# 15326    0.0
# Name: result1, dtype: float64
# 9,WSH,2015,0
# 15368    1.0
# Name: result1, dtype: float64
# 12,CHI,2015,1
# 15351    1.0
# Name: result1, dtype: float64
# 10,HOU,2015,1
# 15273    0.0
# Name: result1, dtype: float64
# 5,LAR,2015,0
# 15444    1.0
# Name: result1, dtype: float64
# 16,MIN,2015,1
# 15448    0.0
# Name: result1, dtype: float64
# 17,ATL,2015,0
# 17002.9395858
# 15483    0.0
# Name: result1, dtype: float64
# 1,MIA,2016,0
# 15544    1.0
# Name: result1, dtype: float64
# 5,ATL,2016,1
# 15564    0.0
# Name: result1, dtype: float64
# 6,NYJ,2016,0
# 15572    0.0
# Name: result1, dtype: float64
# 7,NO,2016,0
# 15595    0.0
# Name: result1, dtype: float64
# 9,JAX,2016,0
# 15623    1.0
# Name: result1, dtype: float64
# 11,TB,2016,1
# 15505    0.0
# Name: result1, dtype: float64
# 3,HOU,2016,0
# 15501    0.0
# Name: result1, dtype: float64
# 2,IND,2016,0
# 15656    0.0
# Name: result1, dtype: float64
# 13,LAR,2016,0
# 15535    0.0
# Name: result1, dtype: float64
# 4,NYG,2016,0
# 15589    0.0
# Name: result1, dtype: float64
# 8,LAC,2016,0
# 15686    1.0
# Name: result1, dtype: float64
# 15,TEN,2016,1
# 15674    0.0
# Name: result1, dtype: float64
# 14,CHI,2016,0
# 15606    0.0
# Name: result1, dtype: float64
# 10,CLE,2016,0
# 15637    0.0
# Name: result1, dtype: float64
# 12,SF,2016,0
# 15702    0.0
# Name: result1, dtype: float64
# 16,MIN,2016,0
# 15723    0.0
# Name: result1, dtype: float64
# 17,WSH,2016,0

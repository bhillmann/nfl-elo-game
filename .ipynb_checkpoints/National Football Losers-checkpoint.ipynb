# %%
import pandas as pd
from util import *
from forecast import *
import matplotlib.pyplot as plt
from hungarian import *

# %%
# %matplotlib inline

# %%
#Load up the elo dataframe
games = Util.read_games("data/nfl_games.csv")
Forecast.forecast(games)
elos = pd.DataFrame(games)

# %%
elos.tail()
# Out:
#              date              elo1              elo2    elo_diff  elo_prob1  \
# 15991  2017-12-31  1617.20456993582  1526.87716569192  168.694984        NaN
# 15992  2017-12-31  1570.90159111721  1536.82159349085  138.017045        NaN
# 15993  2017-12-31  1555.53296643431  1654.01434906643   14.715399        NaN
# 15994  2017-12-31  1437.04615616677  1529.85159039811   14.470194        NaN
# 15995  2017-12-31  1398.79345782117  1353.45953309689  142.949200        NaN
#
#        my_prob1  neutral  playoff  result1  score1  score2  season team1 team2
# 15991  0.725336        0        0     -1.0     NaN     NaN    2017   ATL   CAR
# 15992  0.688795        0        0     -1.0     NaN     NaN    2017   SEA   ARI
# 15993  0.521165        0        0     -1.0     NaN     NaN    2017   DEN    KC
# 15994  0.520812        0        0     -1.0     NaN     NaN    2017   LAC   OAK
# 15995  0.694848        0        0     -1.0     NaN     NaN    2017   LAR    SF

# %%
elos.dtypes
# Out:
# date          object
# elo1          object
# elo2          object
# elo_diff     float64
# elo_prob1    float64
# my_prob1     float64
# neutral        int64
# playoff        int64
# result1      float64
# score1       float64
# score2       float64
# season         int64
# team1         object
# team2         object
# dtype: object

# %%
# Convert to datetime objects
#elos['season'] = pd.to_datetime(elos['season'], errors='coerce')
elos['date'] = pd.to_datetime(elos['date'], errors='coerce')

# %%
elos.dtypes
# Out:
# date         datetime64[ns]
# elo1                 object
# elo2                 object
# elo_diff            float64
# elo_prob1           float64
# my_prob1            float64
# neutral               int64
# playoff               int64
# result1             float64
# score1              float64
# score2              float64
# season                int64
# team1                object
# team2                object
# dtype: object

# %%
elos = elos.sort_values('date', ascending=True)

# %%
week_in_season = []
# Get week in season for forecasting
for group, df in elos.groupby('season'):
    df = df.sort_values('date', ascending=True)
    teams_played = set()
    week = 1
    for team1, team2 in zip(df['team1'], df['team2']):
        if team1 in teams_played or team2 in teams_played:
            week += 1
            teams_played = set()
        teams_played.add(team1)
        teams_played.add(team2)
        week_in_season.append(week)
elos['week_in_season'] = week_in_season
elos.to_csv("data/nfl-games-all.csv", index=False)

# %%
elos[elos['season'].isin([2017])]
# Out:
#             date              elo1              elo2    elo_diff  elo_prob1  \
# 15740 2017-09-07  1687.39515418986  1613.14895156915  171.554005   0.690309
# 15748 2017-09-10  1335.76766004235  1598.85291139428 -176.981615   0.242271
# 15751 2017-09-10   1586.7223860048  1570.90159111721   94.828967   0.614257
# 15752 2017-09-10  1569.47208283577  1530.43602575819  138.641222   0.645400
# 15750 2017-09-10  1353.45953309689  1526.87716569192  -75.443322   0.348849
# 15749 2017-09-10  1398.79345782117  1513.71213747943   -9.066730   0.428652
# 15747 2017-09-10  1383.93471551954  1617.20456993582 -122.987697   0.275152
# 15742 2017-09-10   1459.7151216689  1529.85159039811   19.984055   0.492609
# 15745 2017-09-10  1500.73211234067  1536.82159349085   50.800894   0.541510
# 15744 2017-09-10  1484.12768300401  1451.56552552459  140.998810   0.636826
# 15743 2017-09-10  1504.45790366463  1511.09719571559   92.875366   0.583207
# 15971  0.823139        0        0     -1.0     NaN     NaN    2017    NE
# 15978  0.491448        0        0     -1.0     NaN     NaN    2017   HOU
# 15979  0.619355        0        0     -1.0     NaN     NaN    2017   PHI
# 15988  0.733927        0        0     -1.0     NaN     NaN    2017   TEN
# 15993  0.521165        0        0     -1.0     NaN     NaN    2017   DEN
# 15992  0.688795        0        0     -1.0     NaN     NaN    2017   SEA
# 15991  0.725336        0        0     -1.0     NaN     NaN    2017   ATL
# 15990  0.598082        0        0     -1.0     NaN     NaN    2017   BAL
# 15989  0.634881        0        0     -1.0     NaN     NaN    2017    TB
# 15987  0.525816        0        0     -1.0     NaN     NaN    2017   DET
# 15994  0.520812        0        0     -1.0     NaN     NaN    2017   LAC
# 15985  0.556174        0        0     -1.0     NaN     NaN    2017   PHI
# 15984  0.677918        0        0     -1.0     NaN     NaN    2017   NYG
# 15983  0.854925        0        0     -1.0     NaN     NaN    2017    NE
# 15982  0.784230        0        0     -1.0     NaN     NaN    2017   MIN
# 15981  0.655303        0        0     -1.0     NaN     NaN    2017   MIA
# 15980  0.659391        0        0     -1.0     NaN     NaN    2017   IND
# 15986  0.897530        0        0     -1.0     NaN     NaN    2017   PIT
# 15995  0.694848        0        0     -1.0     NaN     NaN    2017   LAR
#
#       team2  week_in_season
# 15740    KC               1
# 15748   PIT               1
# 15751   SEA               1
# 15752   NYG               1
# 15750   CAR               1
# 15749   IND               1
# 15747   ATL               1
# 15742   OAK               1
# 15745   ARI               1
# 15744   NYJ               1
# 15743   PHI               1
# 15741   JAX               1
# 15746   BAL               1
# 15753    NO               1
# 15754   LAC               1
# 15755   HOU               2
# 15769    GB               2
# 15768    SF               2
# 15767   WSH               2
# 15766   DAL               2
# 15765   NYJ               2
# 15764   MIA               2
# 15763    NE               2
# 15761   TEN               2
# 15760   ARI               2
# 15759   BUF               2
# 15758   CLE               2
# 15757   MIN               2
# 15756   CHI               2
# 15762   PHI               2
# ...     ...             ...
# 15977   NYG              16
# 15976   SEA              16
# 15975   JAX              16
# 15974   DEN              16
# 15973   LAR              16
# 15972   LAC              16
# 15970   MIA              16
# 15969   DET              16
# 15968   CLE              16
# 15967    TB              16
# 15966   ATL              16
# 15971   BUF              16
# 15978   PIT              16
# 15979   OAK              16
# 15988   JAX              17
# 15993    KC              17
# 15992   ARI              17
# 15991   CAR              17
# 15990   CIN              17
# 15989    NO              17
# 15987    GB              17
# 15994   OAK              17
# 15985   DAL              17
# 15984   WSH              17
# 15983   NYJ              17
# 15982   CHI              17
# 15981   BUF              17
# 15980   HOU              17
# 15986   CLE              17
# 15995    SF              17
#
# [256 rows x 15 columns]

# %%
plt.hist(elos.groupby(['season', 'week_in_season']).sum()['elo_diff'])
plt.show()

# %%
# Set infinite values for byes and teams that are really good
INF = 100000

# Copy over results for non-home teams
elos_visitor = elos.copy()
elos_visitor['my_prob1'] = 1 - elos['my_prob1']
elos_visitor['elo_prob1'] = 1 - elos['elo_prob1']
elos_visitor['team1'] = elos['team2']
elos_visitor['team2'] = elos['team1']
elos_visitor['result1'] = 1 - elos['result1']

elos_both = elos.append(elos_visitor)
elos_both = elos_both[elos_both['playoff'] == 0]

results = []
# Predict only SuperBowl era
for year, group in elos_both[elos_both['season'] >= 1967].groupby('season'):
    # Map team to rows
    team_to_number = dict(zip(set(group['team1']), range(len(set(group['team1'])))))
    number_to_team = {v: k for k, v in team_to_number.items()}
    # Get maximum week in season for later
    weeks_in_season = group['week_in_season'].max()
    data = np.ones((len(team_to_number), len(team_to_number)))
    data = data*INF
    # Set up cost matrix
    for _, row in group.iterrows():
        data[team_to_number[row['team1']], row['week_in_season']-1] = row['my_prob1']
    try:
        hungarian = Hungarian(data)
        hungarian.calculate()
        for _team, _week in hungarian.get_results():
            _week = _week+1
            if _week <= weeks_in_season:
                temp = group[group['team1'] == number_to_team[_team]]
                temp = temp[temp['week_in_season'] == _week]['result1'].values[0]
                results.append((_week, number_to_team[_team], year, temp))
    except:
        continue
prior_predictions_hungarian_df = pd.DataFrame(results, columns=['week_in_season', 'team', 'season', 'result'])
prior_predictions_hungarian_df = prior_predictions_hungarian_df.sort_values(['season', 'week_in_season'])
prior_predictions_hungarian_df.to_csv("data/nfl-past-season-predictions-hungarian.csv", index=False)

# %%
losing_weeks = []
for season, group in prior_predictions_hungarian_df.groupby('season'):
    group_errors = group[group['result'] == 1.0]
    if len(group_errors['week_in_season']) > 0:
        losing_week = group_errors['week_in_season'].min()
    else:
        losing_week = group['week_in_season'].max()
    losing_weeks.append([season, losing_week])
losing_weeks_df = pd.DataFrame(losing_weeks, columns=['season', 'week_in_season'])
losing_weeks_df = losing_weeks_df.sort_values(['season', 'week_in_season'])
losing_weeks_df.to_csv("data/nfl-losing-weeks-from-predictions-hungarian.csv", index=False)

# %%
losing_weeks_df['week_in_season'].mean()
# Out:
# 4.490196078431373

# %%
losing_weeks_df['week_in_season'].min()
# Out:
# 1

# %%
losing_weeks_df['week_in_season'].max()
# Out:
# 17

# %%
# Pick Greedily instead
results = []
# Predict only SuperBowl era
for year, group in elos_both[elos_both['season'] >= 1967].groupby('season'):
    selected_teams = set()
    for week, group_week in group.groupby('week_in_season'):
        group_week = group_week.sort_values('my_prob1', ascending=True)
        group_week = group_week[[_ not in selected_teams for _ in group_week['team1']]]
        row = group_week.iloc[0, :]
        results.append([week, row['team1'], year, row['result1']])
        selected_teams.add(row['team1'])
prior_predictions_greedy_df = pd.DataFrame(results, columns=['week_in_season', 'team', 'season', 'result'])
prior_predictions_greedy_df = prior_predictions_greedy_df.sort_values(['season', 'week_in_season'])
prior_predictions_greedy_df.to_csv("data/nfl-past-season-predictions-greedy.csv", index=False)

# %%
losing_weeks = []
for season, group in prior_predictions_greedy_df.groupby('season'):
    group_errors = group[group['result'] == 1.0]
    if len(group_errors['week_in_season']) > 0:
        losing_week = group_errors['week_in_season'].min()
    else:
        losing_week = group['week_in_season'].max()
    losing_weeks.append([season, losing_week])
losing_weeks_greedy_df = pd.DataFrame(losing_weeks, columns=['season', 'week_in_season'])
losing_weeks_greedy_df = losing_weeks_greedy_df.sort_values(['season', 'week_in_season'])
losing_weeks_greedy_df.to_csv("data/nfl-losing-weeks-from-predictions-greedy.csv", index=False)

# %%
losing_weeks_greedy_df['week_in_season'].mean()
# Out:
# 5.9411764705882355

# %%
losing_weeks_greedy_df['week_in_season'].min()
# Out:
# 1

# %%
losing_weeks_greedy_df['week_in_season'].max()
# Out:
# 17
